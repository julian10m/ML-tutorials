# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.datasets import make_blobs
from sklearn.linear_model import LogisticRegression

# %%
def sigmoid(z):
    return 1 / (1 + np.exp(-z))

cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA', '#AAAAFF'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00', '#0000FF'])

x_min, x_max, step = -20, 20.1, 10000
y_min, y_max = 0, 1.1

x = np.linspace(x_min, x_max, step)

fig, (ax1, ax2) = plt.subplots(1,2, sharey=True, figsize = (15, 4))
ax1.plot(x, sigmoid(x), 'k', linewidth = 2)
ax1.scatter(0, 1/2, color = 'k')
ax1.grid(linestyle='--')
ax1.set_xlabel('$z$', size = 16)
ax1.set_ylabel("$\sigma (z)$", size = 16)
ax1.set_title("Sigmoid Function", size = 16)


ax2.plot(x[x>=0], sigmoid(x[x>=0]), 'r', linewidth = 2, label = '$\sigma (z) \geq 1/2, x \geq 0$')
ax2.plot(x[x<0], sigmoid(x[x<0]), 'b', linewidth = 2, label = '$\sigma (z) < 1/2, x < 0$')
ax2.scatter(0, 1/2, color = 'k')
ax2.grid(linestyle='--')
ax2.set_xlabel('$z$', size = 16)
ax2.set_ylabel("$\sigma (z)$", size = 16)
ax2.set_title("Sigmoid Function", size = 16)
ax2.legend(fontsize = 16, loc = 'upper left')
plt.show()

# %%
clf = LogisticRegression()
fig, ax = plt.subplots(2, 5, figsize = (15, 10))
axes = ax.ravel()
for ax in axes:
    X, y = make_blobs(n_samples=[100, 100], 
                      centers=None,
                      n_features=2,
                      cluster_std=1)

    clf.fit(X, y)
    xx, yy = np.meshgrid(np.arange(X[:, 0].min() - 1, X[:, 0].max() + 1, 0.1),
                         np.arange(X[:, 1].min() - 1, X[:, 1].max() + 1, 0.1))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.pcolormesh(xx, yy, Z, cmap = cmap_light)
    ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, alpha = 1, edgecolor="black")
plt.show()

# %%
clf = LogisticRegression()
fig, ax = plt.subplots(2, 5, figsize = (15, 10))
axes = ax.ravel()

for ax in axes:
    X, y = make_blobs(n_samples=[100, 100, 100], 
                      centers=None,
                      n_features=2,
                      cluster_std=1)
    
    clf.fit(X, y)
    xx, yy = np.meshgrid(np.arange(X[:, 0].min() - 1, X[:, 0].max() + 1, 0.1),
                         np.arange(X[:, 1].min() - 1, X[:, 1].max() + 1, 0.1))
    Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    Z = Z.reshape(xx.shape)
    ax.pcolormesh(xx, yy, Z, cmap = cmap_light)
    ax.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, alpha = 1, edgecolor="black")
plt.show()
